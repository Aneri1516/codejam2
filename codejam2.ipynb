# %%
t=int(input())
for i in range(t):
    s=input()
    lst=list(s)
    l=len(lst)
    lst.insert(0,'(')     #this works
    lst.append(')')
    j=0
    while(j<len(lst)):   #works perfectly
        if lst[j]=='0':
            lst.insert(j,')')
            lst.insert(j+2,'(')
            j+=3
        else:
            j+=1
    
    
    
                    #refining the lst...works perfectly
    if lst[0]=='(' and lst[1]==')':
        lst.pop(0)
        lst.pop(0)
        
    if lst[len(lst)-2]=='(' and lst[len(lst)-1]==')':
        lst.pop(len(lst)-1)
        lst.pop(len(lst)-1)
    
     #now the difficult part starts...
    j=0
    max=1
    p=0
    while(j<len(lst)):
            if lst[j]=='2':
                lst.insert(j,'(')
                lst.insert(j+2,')')
                j+=3
                p=1
            elif lst[j]=='3':
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+3,')')
                lst.insert(j+4,')')
                j+=5
                p=2
                if p>max:
                    max=p
            elif lst[j]=='4':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+4,')')
                lst.insert(j+5,')')
                lst.insert(j+6,')')
                j+=7
                p=3
                if p>max:
                    max=p
            elif lst[j]=='5':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+5,')')
                lst.insert(j+6,')')
                lst.insert(j+7,')')
                lst.insert(j+8,')')
                j+=9
                p=4
                if p>max:
                    max=p
            elif lst[j]=='6':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+6,')')
                lst.insert(j+7,')')
                lst.insert(j+8,')')
                lst.insert(j+9,')')
                lst.insert(j+10,')')
                j+=11
                p=5
                if p>max:
                    max=p
            elif lst[j]=='7':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+7,')')
                lst.insert(j+8,')')
                lst.insert(j+9,')')
                lst.insert(j+10,')')
                lst.insert(j+11,')')
                lst.insert(j+12,')')
                j+=13
                p=6
                if p>max:
                    max=p
            elif lst[j]=='8':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+8,')')
                lst.insert(j+9,')')
                lst.insert(j+10,')')
                lst.insert(j+11,')')
                lst.insert(j+12,')')
                lst.insert(j+13,')')
                lst.insert(j+14,')')
                j+=15
                p=7
                if p>max:
                    max=p
            elif lst[j]=='9':
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                lst.insert(j,'(')
                
                lst.insert(j+9,')')
                lst.insert(j+10,')')
                lst.insert(j+11,')')
                lst.insert(j+12,')')
                lst.insert(j+13,')')
                lst.insert(j+14,')')
                lst.insert(j+15,')')
                lst.insert(j+16,')')
                j+=17
                p=8
                if p>max:
                    max=p
            else:
                j+=1
    #print(lst) 
    #popping the pairs
    k=1
    k1=0
    while(k<=max):
        k1=0
        while(k1<len(lst)-1):
            if lst[k1]==')' and lst[k1+1]=='(':
                lst.pop(k1)
                lst.pop(k1)
            if lst[k1]=='(' and lst[k1+1]==')':
                lst.pop(k1)
                lst.pop(k1)
                
            else:
                k1+=1
        k+=1
        str1 = ''.join(lst)
        
    print("Case #"+str(i+1)+": "+str1)
# Out:
# 3
# 123
# Case #1: (1(2(3)))
# 11000234
# Case #2: (11)000((2(3(4))))
# 43432
# Case #3: ((((4)3(4)3)2))
